# %%
import pandas as pd

# %%
df = pd.read_csv('E:/OneDrive/Development/github/python/libs_and_topics/pandas/schafer/data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('E:/OneDrive/Development/github/python/libs_and_topics/pandas/schafer/data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['ConvertedComp'].head(15)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8     116000.0
# 9          NaN
# 10     32315.0
# 11     40070.0
# 12     14268.0
# 13     38916.0
# 14     66000.0
# 15         NaN
# Name: ConvertedComp, dtype: float64

# %%
# get median of column
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
# get median of every column
df.median()
# Out:
# C:\Users\Rodrigo\AppData\Local\Temp/ipykernel_10220/275549284.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
# get statistical overview from df
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
# count rows in a column
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
# count totals for particular values in a particular column
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['SOAccount']
# Out:
# Respondent
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    NaN
# 64867    NaN
# 64898    NaN
# 64925    NaN
# 65112    NaN
# Name: SOAccount, Length: 64461, dtype: object

# %%
# get shema info
# the schema is the table with the questions
schema_df.loc['SOAccount']
# Out:
# QuestionText    Do you have a Stack Overflow account?
# Name: SOAccount, dtype: object

# %%
# count ocurrences of a value in a column
df['SOAccount'].value_counts()
# Out:
# Yes                        47275
# No                          6101
# Not sure/can't remember     3429
# Name: SOAccount, dtype: int64

# %%
# get the percentage of ocurrences corresponding to each value in a column
df['SOAccount'].value_counts(normalize=True)
# Out:
# Yes                        0.832233
# No                         0.107403
# Not sure/can't remember    0.060364
# Name: SOAccount, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Kiribati                1
# Nauru                   1
# Lesotho                 1
# Saint Lucia             1
# Marshall Islands        1
# Name: Country, Length: 183, dtype: int64

# %%
# group by values on a column
country_grp = df.groupby(['Country'])

# %%
# get data from a group
country_grp.get_group('India')
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
# filter by specific value on a column
filt = df['Country'] == 'India'

# %%
# count ocurrences of values on a column
df.loc[filt]['SOAccount'].value_counts()
# Out:
# Yes                        5920
# No                          471
# Not sure/can't remember     367
# Name: SOAccount, dtype: int64

# %%
# get schema info and percentage of ocurrences pervalue from a specific column
country_grp['SOAccount'].value_counts(normalize=True).loc['China']
# Out:
# SOAccount
# Yes                        0.897810
# No                         0.062044
# Not sure/can't remember    0.040146
# Name: SOAccount, dtype: float64

# %%
# get median for specific value on specific column
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
# get median and mean for specific value on specific column
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
# filter column by value
filt = df['Country'] == 'India'

# %%
# add all ocurrences containing certain text on a specific column
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
# add all ocurrences containing certain text on a specific column and show totals and schema
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
# count ocurrences of values and show schema
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Kiribati                1
# Nauru                   1
# Lesotho                 1
# Saint Lucia             1
# Marshall Islands        1
# Name: Country, Length: 183, dtype: int64

# %%
# add all ocurrences containing certain text on a specific column and show schema
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
# create a data frame with specific columns
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                   Country  LanguageWorkedWith
# United States       12469                5964
# India                8403                2670
# United Kingdom       3896                1621
# Germany              3890                1712
# Canada               2191                1011
# ...                   ...                 ...
# Kiribati                1                   0
# Nauru                   1                   0
# Lesotho                 1                   0
# Saint Lucia             1                   1
# Marshall Islands        1                   0
#
# [183 rows x 2 columns]

# %%
# rename columns / Keys
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                        NumRespondents  NumKnowsPython
# United States                   20949           10083
# India                            9061            3105
# Germany                          5866            2451
# United Kingdom                   5737            2384
# Canada                           3395            1558
# ...                               ...             ...
# Dominica                            1               1
# Tonga                               1               0
# Sao Tome and Principe               1               1
# Saint Kitts and Nevis               1               0
# Brunei Darussalam                   1               0
#
# [179 rows x 2 columns]

# %%
# append column with operations
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                   NumRespondents  NumKnowsPython  PctKnowsPython
# United States              12469            5964       47.830620
# India                       8403            2670       31.774366
# United Kingdom              3896            1621       41.606776
# Germany                     3890            1712       44.010283
# Canada                      2191            1011       46.143314
# ...                          ...             ...             ...
# Kiribati                       1               0        0.000000
# Nauru                          1               0        0.000000
# Lesotho                        1               0        0.000000
# Saint Lucia                    1               1      100.000000
# Marshall Islands               1               0        0.000000
#
# [183 rows x 3 columns]

# %%
# sort
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Gabon                                              1               1
# Saint Lucia                                        1               1
# Micronesia, Federated States of...                 1               1
# Montenegro                                        13               9
# Brunei Darussalam                                  3               2
# Guyana                                             5               3
# Swaziland                                          7               4
# Iceland                                           53              28
# Finland                                          349             183
# Uganda                                            81              42
# Belize                                             4               2
# Solomon Islands                                    2               1
# Burkina Faso                                       6               3
# ...
